-- %%
-- SELECT * FROM nyc_gold.yellow_taxi_gold.monthly_avg_trip_distance_by_vendor

-- SELECT to_date(tpep_pickup_datetime) as trip_date, vendor_id, COUNT(*) as trip_count
-- FROM nyc_silver.yellow_taxi_silver.yellow_taxi_transformed
-- GROUP BY to_date(tpep_pickup_datetime), vendor_id
-- ORDER BY trip_count DESC
-- LIMIT 10

-- SELECT vendor_id, COUNT(*) as total_trips
-- FROM nyc_silver.yellow_taxi_silver.yellow_taxi_transformed
-- GROUP BY vendor_id
-- ORDER BY total_trips DESC

-- SELECT * FROM nyc_gold.yellow_taxi_gold.monthly_revenue_by_vendor

-- SELECT COUNT(*) FROM nyc_gold.yellow_taxi_gold.weekly_revenue_by_vendor

-- SELECT COUNT(*) FROM nyc_gold.yellow_taxi_gold.daily_revenue_by_vendor

-- SELECT * FROM nyc_gold.yellow_taxi_gold.top_pickup_locations
